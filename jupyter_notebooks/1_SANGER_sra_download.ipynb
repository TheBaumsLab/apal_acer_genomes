# %%
import pandas as pd
import numpy as np
import subprocess
import glob

# %%
# !cat ../SraRunTable.txt
# Out:
# Run,Assay Type,AvgSpotLen,Bases,BioProject,BioSample,Bytes,Center Name,Collection_Date,Consent,DATASTORE filetype,DATASTORE provider,DATASTORE region,Experiment,geo_loc_name_country,geo_loc_name_country_continent,geo_loc_name,Instrument,Library Name,LibraryLayout,LibrarySelection,LibrarySource,Organism,Platform,ReleaseDate,create_date,version,Sample Name,SRA Study,BioSampleModel,isolate,isolation_source,tissue,collected_by,dev_stage,Disease_inoculation,Frag_number,full_id,genet,sampling_timepoint,Temp,Temperature_treatment,genotype,treatment,BREED,fastq.gz_file_name,Host,cell_line,source_name
# ...

# %%
task = "sra_download"
mem = "128"
cpus = "40"
outpath = "/storage/home/nsl5160/scratch/sanger_reannotate/sra"
runtable = "../SraRunTable.txt"
subprocess.run(["sbatch --mem=" + mem + "g --ntasks=" + 
     cpus + " ../" + task + ".sh " + 
     outpath + " " + runtable], shell=True)
# Out:
# Submitted batch job 14018058
# CompletedProcess(args=['sbatch --mem=128g --ntasks=40 ../sra_download.sh /storage/home/nsl5160/scratch/sanger_reannotate/sra ../SraRunTable.txt'], returncode=0)
